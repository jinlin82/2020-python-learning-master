# %%
import numpy as np
x=np.arange(0,100)
y=x*2
z=x**2

# %% [markdown]
# ## Excercise 1
#
# 1. Create a figure object called fig using plt.figure()
# 2. Use add_axes to add an axis to the figure canvas at [0,0,1,1]
# 3. Plot (x,y) on that axes and set the labels and titles

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Line graph')
# Out:
# Text(0.5, 1.0, 'Line graph')

# %% [markdown]
# ## Excercise 2
#
# Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ## Now plot(x,y) on both axes. And call your figure object to show it.

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.2,0.2])
ax1.plot(x,y)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title('Line graph 1')

ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Line graph 2')
# Out:
# Text(0.5, 1.0, 'Line graph 2')

# %% [markdown]
# ## Excercise 3
#
# Create the plot by adding two axes to a figure obeject at [0,0,1,1] and ]0.2,0.5,.4,.4]

# %%
fig=plt.figure()
ax1=fig.add_axes([0,0,1,1])
ax2=fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ## Now use x,y and z arrays to recreate the plot below. Notice the xlimits and ylimits on the inserted plot:

# %%
ax1.plot(x,z)
ax1.set_xlabel('X')
ax1.set_ylabel('Z')
ax1.set_title('Z-X')

ax2.plot(x,y)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Y-X')
ax2.set_xlim(20,22)
ax2.set_ylim(30,50)

fig

# %% [markdown]
# ## Excercise 4
#
# Use plt.subplots(nrows=1, ncols=2) to create the plot below.

# %%
plt.subplots(nrows=1,ncols=2) # tuple(figure,array([axes0,axes1]))
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000268FAA8CD48>,
# ...
#        dtype=object))

# %% [markdown]
# ## Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,'bo',lw=2)
axes[1].plot(x,z,'r--',lw=3)

# %% [markdown]
# ## Resize the plot by adding the figsize() argument in plt.subplots() are copying and passing the previous code

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(10,4))
axes[0].plot(x,y,'bo',lw=2)
axes[1].plot(x,z,'r--',lw=3)
